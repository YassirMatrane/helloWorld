# %%
import numpy as np
import pandas as pd
product = "start"
df = {"product":[],"prix 0":[],"prix 1":[],"prix 2":[],"prix 3":[],"prix 4":[],"prix 5":[],"prix 6":[]}
while product !="":
    df["product"].append(input("entrez le nom du produit"))
    for i in range(7):
        prix = input("entrez le prix et l'entreprise du produit")
        if prix !="":
            df["prix "+str(i)].append(prix)
        else:
            df["prix "+str(i)].append(np.nan)
            product = ""
            for j in range(i+1,7):
                df["prix "+str(j)].append(np.nan)
            break
            
csvFile = pd.DataFrame(df,columns=df.keys())
csvFile1 = pd.read_csv("products.csv",index_col=0)
csvFile2 = pd.concat([csvFile,csvFile1],sort=False)
csvFile2.to_csv("products.csv")
df = pd.read_csv("products.csv",index_col=0)
df.head()
# Out:
# entrez le nom du produitproduct 4
# entrez le prix et l'entreprise du produit10000 DH para
# entrez le prix et l'entreprise du produit

# %%
#df = df.reindex(columns=['product',"prix 0","prix 1","prix 2","prix 3","prix 4","prix 5","prix 6"])
polarityWords1 = ["مسامحه","وقت","حليب","يحفظ","وبعد","شر","شاء","سعيد","نصف","تصريح","تاريخيه","وثاءق","تعتبر","كنز","حفاظ","","","","","","","","","","","جهه","مجتمع","طبق","تربيه","بمناسبه","تهدي","كلمه","عريان","قديم","انسان","فهمت","يفرج","كاريزما","اطيب","ثقه","براءه","ملاحظه","نلعب","عكس","فشكل","تمثل","اكثريه","يكمل","دراسه","متعلم","تخاف","راقي","تعامل","اقسم","اتصلت","بصديقه","نتاكد","امر","فطريق","حمد","لاعب","يقدر","مباراه","وبالنسبه","صاحب","مواجع","قالت","مصر","اخر","شعبيه","وقع","شاء","ميعاد","خرجت","طريق","احتراما","هوايه","متعصب","امل","نصيحه","ضاحكه","منتصف","مرحباا","استقبال","تربح","تبدا","شخصي","مشروع","تفكر","صندوق","خارج","فكر","مساعدت","واستقبال","فيلم","خارج","موضوع","كامل","خروج","اعلامي","يصل","عالميه","تعاون","يقدر","","لدعم","فنانه","رمز","فلسطينيه","فتاه","قتلت","كانت","عالقه","روعه","شكرا","يوفق","مسار","مباشره","يسعد","عرس","نداء","هام","نحقق","بلاد","حاضر","بصمه","شكر","مساند","موعد","اكيد","مرحبا","نضحك","مصيبه","نتفكر","صراحه","تزوج","احسن","خاارج","يتبع","حقيقي","حب","تحيه","يقول","فتنه","عداله","نهار","عمل","اتحاد","نتحد","جواب","مباركه","صحه","نجاح","مزاج","ساعه","وصل","ساكن","برنامج","عيد","شعر","عداله","شباب","لعبه","صوت","هدف","صحيح","برنامج","موضوع","يختار","جبال","تعليم","مصداقيه","مسلسل","سيد","تجربه","خير","مساعده","طلب","كاميرا","كبير","حكمه","فكره","طريق","جمهور","صحابا"]
polarityWords3 = ["","","","","","","","","","استاذ","فقط","اشهر","قطيع","بخير","ومخطط","تخيل","لغه","احمر","لحم","تزاد","ثمن","عريس","سعيده","تمويه","عرف","احساس","كره","دليل","اكد","قاضيه","سابقه","صديق","دم","جفاف","ويتصور","مصور","مرشح","قيمه","نجمع","تقصف","جبهه","خطير","فشهر","لكاس","كلام","تبرير","هزيمه","منتخب","شعب","قوه","عظيم","فرصه","يرجع","وضعيه","امور","تحسن","نضال","ايام","ترتيب","مقابل","كاميره","خفيه","قوم","جهوي","مساعدت","واستقبال","فيلم","خارج","موضوع","كامل","خروج","اعلامي","يصل","عالميه","تعاون","يقدر","","لدعم","فنانه","رمز","فلسطينيه","فتاه","قتلت","كانت","عالقه","روعه","شكرا","يوفق","مسار","مباشره","يسعد","عرس","نداء","هام","نحقق","بلاد","حاضر","بصمه","شكر","مساند","موعد","اكيد","مرحبا","نضحك","مصيبه","نتفكر","صراحه","تزوج","احسن","خاارج","يتبع","حقيقي","حب","تحيه","يقول","فتنه","عداله","نهار","عمل","اتحاد","نتحد","جواب","مباركه","صحه","نجاح","مزاج","ساعه","وصل","ساكن","برنامج","عيد","شعر","عداله","شباب","لعبه","صوت","هدف","صحيح","برنامج","موضوع","يختار","جبال","تعليم","مصداقيه","مسلسل","سيد","تجربه","خير","مساعده","طلب","كاميرا","كبير","حكمه","فكره","طريق","جمهور","صحابا"]

# %%
df.at[0,"prix 0"] = "200DH"

# %%
df.iloc[i,]
